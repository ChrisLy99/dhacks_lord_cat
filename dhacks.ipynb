# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import dhacks as dh

# %%
# %load_ext autoreload
# %autoreload 2

# %%
datasets = dh.read_data()

# %%
b_h = datasets[0]

# %%
b_a = datasets[1]

# %%
h_a = datasets[2]

# %%
h1 = datasets[3]

# %%
h2 = datasets[4]

# %%
for df in datasets:
    display(df)
# Out:
#             Date  Origin Movement ID  \
# 0     06/09/2019                3396
# 1     04/28/2019                3603
# 2     05/18/2019                3603
# 3     04/18/2019                3792
# 4     04/08/2019                3792
# ...          ...                 ...
# 3253  01/06/2019                3396
# 3254  01/24/2019                3396
# 3255  01/09/2019                3760
# 3256  02/04/2019                3760
# 3257  03/04/2019                3760
#
#                                     Origin Display Name  \
# 0     The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 1                        Embarcadero, San Francisco, CA
# 2                        Embarcadero, San Francisco, CA
# 3     Oracle Park, 24 Willie Mays Plaza, San Francis...
# 4     Oracle Park, 24 Willie Mays Plaza, San Francis...
# ...                                                 ...
# 3253  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# 3254  The Palace Of Fine Arts, 3601 Lyon St, San Fra...
# ...

# %%
for df in datasets:
    display(df.head())
# Out:
#          Date  Origin Movement ID  \
# 0  06/09/2019                3396
# 1  04/28/2019                3603
# 2  05/18/2019                3603
# 3  04/18/2019                3792
# 4  04/08/2019                3792
#
#                                  Origin Display Name  Destination Movement ID  \
# 0  The Palace Of Fine Arts, 3601 Lyon St, San Fra...                     3603
# 1                     Embarcadero, San Francisco, CA                     3394
# 2                     Embarcadero, San Francisco, CA                     3394
# 3  Oracle Park, 24 Willie Mays Plaza, San Francis...                     3603
# 4  Oracle Park, 24 Willie Mays Plaza, San Francis...                     3603
#
#                Destination Display Name  Daily Mean Travel Time (Seconds)  \
# 0        Embarcadero, San Francisco, CA                            1588.0
# 1  Fisherman's Wharf, San Francisco, CA                             639.0
# ...

# %%
b_ID = b_a['Origin Movement ID'].unique()

# %%
b_ID
# Out:
# array([3603, 3692, 3760], dtype=int64)

# %%
h_ID = h_a['Origin Movement ID'].unique()

# %%
h_ID
# Out:
# array([3394, 3792, 3396], dtype=int64)

# %%
h1[h1.dstid.isin(b_ID) & h1.sourceid.isin(h_ID)]
# Out:
#         sourceid  dstid  hod  mean_travel_time  \
# 52561       3792   3692    4            427.57
# 59628       3792   3760    2            587.71
# 60161       3792   3760   10            763.96
# 61013       3792   3760   19            846.39
# 61494       3792   3760   20            722.38
# ...          ...    ...  ...               ...
# 599978      3792   3692   14            558.29
# 601348      3792   3603   21            412.14
# 613610      3792   3603   20            439.01
# 614064      3792   3603   22            418.40
# 630898      3792   3692   23            409.14
#
#         standard_deviation_travel_time  geometric_mean_travel_time  \
# 52561                           263.28                      358.84
# 59628                           152.35                      565.07
# 60161                           257.19                      723.84
# 61013                           357.85                      786.31
# ...

# %%
h2[h2.dstid.isin(b_ID) & h2.sourceid.isin(h_ID)]
# Out:
#         sourceid  dstid  hod  mean_travel_time  \
# 2019        3792   3692   11            609.38
# 19769       3792   3692    8            621.55
# 50066       3792   3760   13            817.13
# 50421       3792   3603    6            382.44
# 82963       3792   3760   21            682.88
# ...          ...    ...  ...               ...
# 588440      3792   3603    5            420.36
# 588451      3792   3760   12            804.23
# 589867      3792   3603   18            578.17
# 593612      3792   3760   10            836.29
# 614179      3792   3760    0            583.31
#
#         standard_deviation_travel_time  geometric_mean_travel_time  \
# 2019                            287.59                      556.16
# 19769                           280.59                      567.19
# 50066                           323.04                      763.42
# 50421                           116.47                      371.55
# ...

# %%
sns.distplot(h1[h1.dstid.isin(b_ID) & h1.sourceid.isin(h_ID)].hod)

# %%
sns.distplot(h2[h2.dstid.isin(b_ID) & h2.sourceid.isin(h_ID)].hod)
